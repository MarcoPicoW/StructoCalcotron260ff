# %%
import numpy, scipy, math, handcalcs.render, forallpeople
from math import sqrt, pi, sin, tan, cos
forallpeople.environment('structural', top_level=True)
handcalcs.save_config()

# %%
f_sd = 300*N/mm**2
E_s = 205000 * N /mm**2  #SIA 262 3.2.2.4

# %%
# %%tex params 5
# k_g = 1.2* (mm**(-1))
# tau_cd = 1.2  * N/mm**2
# Out:
# \[
# \begin{aligned}
# k_{g} &= 0.00120\ \mathrm{μm}^{-1} \;
#  &\tau_{cd} &= 1.20000\ \mathrm{MPa} \;
# \end{aligned}
# \]

# %%
# %%tex
# d = 430* mm
# d_v = 430 *mm
# m_Ed = 0.87
# m_Rd = 1
# epsilon_v = f_sd/E_s * (m_Ed/m_Rd)
# k_d = 1 / (1 +(epsilon_v * d * k_g) )
# v_Rd = k_d * tau_cd * d_v
# V_Rd = v_Rd * 2000*mm
# Out:
# \[
# \begin{aligned}
# d &= 430 \cdot \mathrm{mm}  = 430 \cdot mm &= 430.000\ \mathrm{mm}
# \\[10pt]
# d_{v} &= 430 \cdot \mathrm{mm}  = 430 \cdot mm &= 430.000\ \mathrm{mm}
# \\[10pt]
# m_{Ed} &= 0.870 \;
# \\[10pt]
# m_{Rd} &= 1 \;
# \\[10pt]
# \epsilon_{v} &= \frac{ f_{sd} }{ E_{s} } \cdot \left( \frac{ m_{Ed} }{ m_{Rd} } \right)  = \frac{ 300.000\ \mathrm{MPa} }{ 205.000\ \mathrm{GPa} } \cdot \left( \frac{ 0.870 }{ 1 } \right) &= 0.001
# \\[10pt]
# k_{d} &= \frac{ 1 }{ 1 + \left( \epsilon_{v} \cdot d \cdot k_{g} \right) }  = \frac{ 1 }{ 1 + \left( 0.001 \cdot 430.000\ \mathrm{mm} \cdot 0.001\ \mathrm{μm}^{-1} \right) } &= 0.604
# \\[10pt]
# v_{Rd} &= k_{d} \cdot \tau_{cd} \cdot d_{v}  = 0.604 \cdot 1.200\ \mathrm{MPa} \cdot 430.000\ \mathrm{mm} &= 311.414\ \mathrm{kN/m}
# \\[10pt]
# V_{Rd} &= v_{Rd} \cdot 2000 \cdot \mathrm{mm}  = 311.414\ \mathrm{kN/m} \cdot 2000 \cdot mm &= 622.829\ \mathrm{kN}
# \end{aligned}
# \]

# %%
# %%render short 4
# d = 455* mm
# d_v = 430 *mm
# m_Ed = 0.87
# m_Rd = 1
# epsilon_v = f_sd/E_s * (m_Ed/m_Rd)
# k_d = 1 / (1 +(epsilon_v * d * k_g) )
# v_Rd = k_d * tau_cd * d_v
# V_Rd = v_Rd * 2000*mm
# Out:
# \[
# \begin{aligned}
# d &= 455 \cdot \mathrm{mm}  = 455 \cdot mm &= 455.0000\ \mathrm{mm}
# \\[10pt]
# d_{v} &= 430 \cdot \mathrm{mm}  = 430 \cdot mm &= 430.0000\ \mathrm{mm}
# \\[10pt]
# m_{Ed} &= 0.8700 \;
# \\[10pt]
# m_{Rd} &= 1 \;
# \\[10pt]
# \epsilon_{v} &= \frac{ f_{sd} }{ E_{s} } \cdot \left( \frac{ m_{Ed} }{ m_{Rd} } \right)  = \frac{ 300.0000\ \mathrm{MPa} }{ 205.0000\ \mathrm{GPa} } \cdot \left( \frac{ 0.8700 }{ 1 } \right) &= 0.0013
# \\[10pt]
# k_{d} &= \frac{ 1 }{ 1 + \left( \epsilon_{v} \cdot d \cdot k_{g} \right) }  = \frac{ 1 }{ 1 + \left( 0.0013 \cdot 455.0000\ \mathrm{mm} \cdot 0.0012\ \mathrm{μm}^{-1} \right) } &= 0.5899
# \\[10pt]
# v_{Rd} &= k_{d} \cdot \tau_{cd} \cdot d_{v}  = 0.5899 \cdot 1.2000\ \mathrm{MPa} \cdot 430.0000\ \mathrm{mm} &= 304.3976\ \mathrm{kN/m}
# \\[10pt]
# V_{Rd} &= v_{Rd} \cdot 2000 \cdot \mathrm{mm}  = 304.3976\ \mathrm{kN/m} \cdot 2000 \cdot mm &= 608.7952\ \mathrm{kN}
# \end{aligned}
# \]

# %%
# %%render short 4
# d = 655* mm
# d_v = 630* mm
# m_Ed = 1.5
# m_Rd = 1
# epsilon_v = f_sd/E_s * (m_Ed/m_Rd)
# k_d = 1 / (1 +(epsilon_v * d * k_g) )
# v_Rd = k_d * tau_cd * d_v
# V_Rd = v_Rd * 2000*mm
# Out:
# \[
# \begin{aligned}
# d &= 655 \cdot \mathrm{mm}  = 655 \cdot mm &= 655.0000\ \mathrm{mm}
# \\[10pt]
# d_{v} &= 630 \cdot \mathrm{mm}  = 630 \cdot mm &= 630.0000\ \mathrm{mm}
# \\[10pt]
# m_{Ed} &= 1.5000 \;
# \\[10pt]
# m_{Rd} &= 1 \;
# \\[10pt]
# \epsilon_{v} &= \frac{ f_{sd} }{ E_{s} } \cdot \left( \frac{ m_{Ed} }{ m_{Rd} } \right)  = \frac{ 300.0000\ \mathrm{MPa} }{ 205.0000\ \mathrm{GPa} } \cdot \left( \frac{ 1.5000 }{ 1 } \right) &= 0.0022
# \\[10pt]
# k_{d} &= \frac{ 1 }{ 1 + \left( \epsilon_{v} \cdot d \cdot k_{g} \right) }  = \frac{ 1 }{ 1 + \left( 0.0022 \cdot 655.0000\ \mathrm{mm} \cdot 0.0012\ \mathrm{μm}^{-1} \right) } &= 0.3669
# \\[10pt]
# v_{Rd} &= k_{d} \cdot \tau_{cd} \cdot d_{v}  = 0.3669 \cdot 1.2000\ \mathrm{MPa} \cdot 630.0000\ \mathrm{mm} &= 277.3940\ \mathrm{kN/m}
# \\[10pt]
# V_{Rd} &= v_{Rd} \cdot 2000 \cdot \mathrm{mm}  = 277.3940\ \mathrm{kN/m} \cdot 2000 \cdot mm &= 554.7879\ \mathrm{kN}
# \end{aligned}
# \]

# %%
# %%render short 4
# d = 655* mm
# d_v = 630* mm
# m_Ed = 0.65
# m_Rd = 1
# epsilon_v = f_sd/E_s * (m_Ed/m_Rd)
# k_d = 1 / (1 +(epsilon_v * d * k_g) )
# v_Rd = k_d * tau_cd * d_v
# V_Rd = v_Rd * 2000*mm
# Out:
# \[
# \begin{aligned}
# d &= 655 \cdot \mathrm{mm}  = 655 \cdot mm &= 655.0000\ \mathrm{mm}
# \\[10pt]
# d_{v} &= 630 \cdot \mathrm{mm}  = 630 \cdot mm &= 630.0000\ \mathrm{mm}
# \\[10pt]
# m_{Ed} &= 0.6500 \;
# \\[10pt]
# m_{Rd} &= 1 \;
# \\[10pt]
# \epsilon_{v} &= \frac{ f_{sd} }{ E_{s} } \cdot \left( \frac{ m_{Ed} }{ m_{Rd} } \right)  = \frac{ 300.0000\ \mathrm{MPa} }{ 205.0000\ \mathrm{GPa} } \cdot \left( \frac{ 0.6500 }{ 1 } \right) &= 0.0010
# \\[10pt]
# k_{d} &= \frac{ 1 }{ 1 + \left( \epsilon_{v} \cdot d \cdot k_{g} \right) }  = \frac{ 1 }{ 1 + \left( 0.0010 \cdot 655.0000\ \mathrm{mm} \cdot 0.0012\ \mathrm{μm}^{-1} \right) } &= 0.5722
# \\[10pt]
# v_{Rd} &= k_{d} \cdot \tau_{cd} \cdot d_{v}  = 0.5722 \cdot 1.2000\ \mathrm{MPa} \cdot 630.0000\ \mathrm{mm} &= 432.5788\ \mathrm{kN/m}
# \\[10pt]
# V_{Rd} &= v_{Rd} \cdot 2000 \cdot \mathrm{mm}  = 432.5788\ \mathrm{kN/m} \cdot 2000 \cdot mm &= 865.1576\ \mathrm{kN}
# \end{aligned}
# \]

# %%
# %%render short 4
# d =855* mm
# d_v = 820* mm
# m_Ed = 1.5
# m_Rd = 1
# epsilon_v = f_sd/E_s * (m_Ed/m_Rd)
# k_d = 1 / (1 +(epsilon_v * d * k_g) )
# v_Rd = k_d * tau_cd * d_v
# V_Rd = v_Rd * 2000*mm
# Out:
# \[
# \begin{aligned}
# d &= 855 \cdot \mathrm{mm}  = 855 \cdot mm &= 855.0000\ \mathrm{mm}
# \\[10pt]
# d_{v} &= 820 \cdot \mathrm{mm}  = 820 \cdot mm &= 820.0000\ \mathrm{mm}
# \\[10pt]
# m_{Ed} &= 1.5000 \;
# \\[10pt]
# m_{Rd} &= 1 \;
# \\[10pt]
# \epsilon_{v} &= \frac{ f_{sd} }{ E_{s} } \cdot \left( \frac{ m_{Ed} }{ m_{Rd} } \right)  = \frac{ 300.0000\ \mathrm{MPa} }{ 205.0000\ \mathrm{GPa} } \cdot \left( \frac{ 1.5000 }{ 1 } \right) &= 0.0022
# \\[10pt]
# k_{d} &= \frac{ 1 }{ 1 + \left( \epsilon_{v} \cdot d \cdot k_{g} \right) }  = \frac{ 1 }{ 1 + \left( 0.0022 \cdot 855.0000\ \mathrm{mm} \cdot 0.0012\ \mathrm{μm}^{-1} \right) } &= 0.3075
# \\[10pt]
# v_{Rd} &= k_{d} \cdot \tau_{cd} \cdot d_{v}  = 0.3075 \cdot 1.2000\ \mathrm{MPa} \cdot 820.0000\ \mathrm{mm} &= 302.5649\ \mathrm{kN/m}
# \\[10pt]
# V_{Rd} &= v_{Rd} \cdot 2000 \cdot \mathrm{mm}  = 302.5649\ \mathrm{kN/m} \cdot 2000 \cdot mm &= 605.1297\ \mathrm{kN}
# \end{aligned}
# \]

# %%
# %%render short 4
# Out:
#   Cell In[82], line 1
#     Delta and sigma = 5
#     ^
# SyntaxError: cannot assign to expression
